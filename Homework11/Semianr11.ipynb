# %% [markdown]
# ### Дана функция f(x) =  -12x^4*sin(cos(x)) - 18x^3+5x^2 + 10x - 30
#
# 1. Определить корни
# 2. Найти интервалы, на которых функция возрастает
# 3. Найти интервалы, на которых функция убывает
# 4. Построить график
# 5. Вычислить вершину
# 6. Определить промежутки, на котором f > 0 (производная)
# 7. Определить промежутки, на котором f < 0 (производная)

# %%
from sympy import *

# %%
x = Symbol('x')
y = -12*(x**4)*sin(cos(x))-18*(x**3)+5*(x**2)+10*x-30
y
# Out:
# -12*x**4*sin(cos(x)) - 18*x**3 + 5*x**2 + 10*x - 30

# %%
h = plot(y, (x, -200, 200))

# %% [markdown]
# #### Анализируя график, можно сделать выводы:
# 1. Функция периодическая;
# 2. Так как не указан диапазон "x" можно сделать вывод, что корней - бесконечно много;
# 3. Исходя из этого, интервалов - бесконечно;
# 4. Вершин - бескончено много;
